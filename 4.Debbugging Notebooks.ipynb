# %% [markdown]
# - Brekpoints
# - Stepthrouht code line bu line
# - Variable explorer
# - Debug Console

# %%
#Calculte the final price of an item and pint the final price
item_price = 120.00
tax_rate = 20 #given as percnetage
discount = 10.00

# 1. calcute the taxe to be applied 
tax = item_price * tax_rate / 100

# 2. apply tax to the item price 
# item_price_with_tax = item_price - tax 
item_price_with_tax = item_price + tax 
# 3. apply the flat discount to the item price 
final_price = item_price_with_tax - discount

# print the final price

print(f"Final price is {final_price:2f}")

# %% [markdown]
# Demonstarte step by step

# %%
def calculate_final_price(item_price, tax_rate, discount):
    # 1. calcute the taxe to be applied 
    tax = item_price * tax_rate / 100

    # 2. apply tax to the item price 
    item_price_with_tax = item_price + tax 
    # 3. apply the flat discount to the item price 
    final_price = item_price_with_tax - discount
    return final_price

# %%
#Main Program

item_price = 120.00
tax_rate = 20 #given as percnetage
discount = 10.00

final_price = calculate_final_price(item_price, tax_rate, discount)
print(f"Final price is {final_price:.2f}")
